# %% [markdown]
# # Dynamic Topic Modelling
# With the results got from section 1.3.2, we are applying LdaSeqModel class of gensim to see topics over time
#     <br> topic coherence with DTM

# %%
import re
import numpy as np
import pandas as pd
from pprint import pprint

# Gensim
import gensim
import gensim.corpora as corpora
from gensim.utils import simple_preprocess
from gensim.models import CoherenceModel



# Enable logging for gensim - optional
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)

#import warnings
#warnings.filterwarnings("ignore",category=DeprecationWarning)

#dynamic topic model
from gensim.models import ldaseqmodel
from gensim.corpora import Dictionary, bleicorpus
import numpy
from gensim.matutils import hellinger

warnings.filterwarnings("ignore",category=DeprecationWarning)

# %%
# #load the dictionary and corpora from local file
# loaded_dct = Dictionary.load_from_text('dictRegulations')
# #assert dictionary.token2id == loaded_dct.token2id    #check if it's loaded properly

# loaded_corpus = bleicorpus.BleiCorpus('corpusRegulations')

# # shoorten the dict more to reduce run time
# loaded_dct.filter_extremes(no_below=20, no_above=0.70)

# len(loaded_dct)
# corpus = [loaded_dct.doc2bow(doc) for doc in data_clean]

# #PART A: devided the time as 20 years bucket, 1951-1994, 1994-2008, 2018-2018
# time_slice=[532,688,532]
# ldaseq = ldaseqmodel.LdaSeqModel(corpus=loaded_corpus, id2word=loaded_dct, time_slice=time_slice, num_topics=5)
# ldaseq.print_topics(time=0)
# #started at 3:44

# ldaseq.print_topics(time=0)

# %%
# Pickle
# import pickle
# with open('test.txt', 'wb') as f:
#     pickle.dump(mylist, f)

with open('test.txt', 'rb') as f:
    data_clean = pickle.load(f)
len(data_clean)
# Out:
# 1753

# %%
dictionary = corpora.Dictionary(data_clean)
dictionary.filter_extremes(no_below=5, no_above=0.75)
print('Number of unique tokens: %d' % len(dictionary))

corpus = [dictionary.doc2bow(doc) for doc in data_clean]
print("Corpus is ready")
# Out:
# Number of unique tokens: 6193
# Corpus is ready

# %%
#run DTM model

# commented as it takes around 6 hours to run

# print("Please wait...")
# time_slice=[532,688,533]
# ldaSeqModel_25topics_3timelines = ldaseqmodel.LdaSeqModel(corpus=corpus, id2word=dictionary, time_slice=time_slice, num_topics=25)
# #strated at 12:28
# print("Complete")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\gensim\models\ldaseqmodel.py:290: RuntimeWarning: divide by zero encountered in double_scalars
#   convergence = np.fabs((bound - old_bound) / old_bound)

# %%
ldaSeqModel_25topics_3timelines.save("ldaSeqModel_25topics_3timelines")
ldaseqmodel.LdaSeqModel?

# %%
list(zip(np.arange(0,25,1),ldaSeqModel_25topics_3timelines.print_topics(time=0)))
# Out:
# [(0,
#   [('type', 0.111585935593222),
#    ('substance', 0.030449934360104305),
#    ('product', 0.02252612618870955),
#    ('mixture', 0.0192433952649569),
#    ('datum', 0.01827720693236932),
#    ('classify', 0.016602099582982113),
#    ('hazard', 0.015842670721823472),
#    ('item', 0.013257522829710516),
#    ('hazardous', 0.012893681505764564),
#    ('schedule', 0.012315958480246747),
#    ('concentration', 0.011973977419779703),
#    ('class', 0.011256906926591944),
#    ('test', 0.011066229916920602),
#    ('classification', 0.009777822285055459),
#    ('violation', 0.009398294891583135),
#    ('table', 0.007755416810216864),
#    ('ingredient', 0.007638730012252727),
#    ('material', 0.007393185749431535),
#    ('liquid', 0.007214206662927904),
#    ('solid', 0.0069134111054569205)]),
#  (1,
#   [('diving', 0.03291052943280768),
#    ('operation', 0.0314281348791484),
#    ('explosive', 0.01791420269042317),
#    ('person', 0.017547735784105158),
#    ('dive', 0.01568524082710644),
#    ('certificate', 0.01284129747658466),
#    ('operator', 0.01221152425940378),
#    ('supervisor', 0.011590734954342735),
#    ('safety', 0.01021846014501938),
#    ('ensure', 0.00972756333670711),
#    ('equipment', 0.009092333790670537),
#    ('include', 0.008467242416776337),
#    ('well', 0.00838896476222835),
#    ('storage', 0.008313967011587407),
#    ('conduct', 0.007282697875629893),
#    ('unit', 0.007019359359788948),
#    ('system', 0.0069354167040104),
#    ('time', 0.0066499380691381945),
#    ('installation', 0.006556133082844446),
#    ('refer', 0.006504027693839019)]),
#  (2,
#   [('point', 0.07983117015751183),
#    ('surface', 0.06872883073781055),
#    ('strip', 0.032970288480184066),
#    ('island', 0.0321686889173985),
#    ('airport', 0.030902681083503445),
#    ('water', 0.028858244003629217),
#    ('outer', 0.02032510891261467),
#    ('approach', 0.020194256397856526),
#    ('shoreline', 0.018311329800912844),
#    ('describe', 0.015964445107318963),
#    ('land', 0.01572761068279352),
#    ('zone', 0.015524562677951777),
#    ('schedule', 0.01403939091924063),
#    ('runway', 0.013561680006263352),
#    ('west', 0.010884608877709194),
#    ('plan', 0.010671921380229134),
#    ('centre', 0.010648480539953984),
#    ('reference', 0.01055322677312276),
#    ('south', 0.009060246148525132),
#    ('elevation', 0.009059406045552425)]),
#  (3,
#   [('system', 0.028147449556516522),
#    ('fire', 0.012409890723617029),
#    ('installation', 0.011974327547913288),
#    ('control', 0.009915557048283287),
#    ('space', 0.009365619542141022),
#    ('standard', 0.008595402567015601),
#    ('design', 0.008389476154827342),
#    ('equipment', 0.00788623279180818),
#    ('require', 0.0076788774762467935),
#    ('water', 0.007476184887737158),
#    ('test', 0.00726682924058195),
#    ('area', 0.007168827971466781),
#    ('pump', 0.007166461054543001),
#    ('gas', 0.007133297226876972),
#    ('power', 0.00711738385252439),
#    ('fit', 0.0068551985566052825),
#    ('requirement', 0.006688078834153118),
#    ('platform', 0.0063991870593859985),
#    ('include', 0.006398090546252332),
#    ('condition', 0.006246673496929967)]),
#  (4,
#   [('claim', 0.028088446680932966),
#    ('lease', 0.02140497867837844),
#    ('cost', 0.01938449018772298),
#    ('work', 0.015730515317679963),
#    ('record', 0.014649602009752013),
#    ('year', 0.011888994315858872),
#    ('respect', 0.011338862917668098),
#    ('mine', 0.010949846185683202),
#    ('area', 0.01055349740798208),
#    ('permit', 0.009940550267348958),
#    ('day', 0.008331215800907447),
#    ('report', 0.00802439924180398),
#    ('land', 0.007889674829409185),
#    ('operator', 0.007256641563071466),
#    ('survey', 0.007251739370598846),
#    ('geophysical', 0.00720677131042248),
#    ('lessee', 0.0071250168302000655),
#    ('fiscal', 0.006781247875469618),
#    ('mineral', 0.006473139909766426),
#    ('map', 0.006383764532110982)]),
#  (5,
#   [('board', 0.03107547729618159),
#    ('marketing', 0.022996383053306316),
#    ('area', 0.022014353238897034),
#    ('person', 0.018165365834496898),
#    ('levy', 0.017370458036748214),
#    ('producer', 0.01647706219242328),
#    ('sor', 0.015506185197961736),
#    ('province', 0.015237831253850644),
#    ('plan', 0.01403774331649431),
#    ('activity', 0.01387105021108212),
#    ('commodity', 0.013323270100419877),
#    ('trade', 0.012923993317319608),
#    ('export', 0.012884410576968425),
#    ('interprovincial', 0.012774736915159764),
#    ('ontario', 0.011236452780005677),
#    ('market', 0.01079311693975346),
#    ('respect', 0.010517428213933241),
#    ('purpose', 0.010124083219240423),
#    ('charge', 0.008752423876330429),
#    ('quebec', 0.008296329909045438)]),
#  (6,
#   [('good', 0.05549945126135639),
#    ('tariff', 0.05036106593171581),
#    ('custom', 0.035001765121061526),
#    ('canada', 0.02984890878355925),
#    ('item', 0.028042191810648362),
#    ('import', 0.01903216112510178),
#    ('remission', 0.0166578273621737),
#    ('duty', 0.01658240355118906),
#    ('january', 0.016504897929278426),
#    ('force', 0.01535894544070531),
#    ('respect', 0.01197307844255527),
#    ('sor', 0.010499806474926505),
#    ('origin', 0.009637452747522141),
#    ('country', 0.008919023644741567),
#    ('schedule', 0.008690687214066397),
#    ('december', 0.007349619755213808),
#    ('grant', 0.007094931233832052),
#    ('day', 0.007057121581525704),
#    ('export', 0.006959793741029488),
#    ('pay', 0.006895550612181295)]),
#  (7,
#   [('application', 0.029442263680557225),
#    ('person', 0.025435230882404562),
#    ('party', 0.022797727551559153),
#    ('provide', 0.016312455056091902),
#    ('day', 0.015271345897013535),
#    ('file', 0.014512585925441104),
#    ('request', 0.01374485818332437),
#    ('appeal', 0.013228960167074429),
#    ('applicant', 0.013045523844836602),
#    ('copy', 0.012488334221441412),
#    ('decision', 0.011706604029491757),
#    ('rule', 0.011572795846033823),
#    ('write', 0.011238912199276438),
#    ('time', 0.010794030174076194),
#    ('hearing', 0.00923278032214376),
#    ('hear', 0.008401157441325672),
#    ('board', 0.008266273186900801),
#    ('evidence', 0.008111216382957288),
#    ('commission', 0.0073511772811430485),
#    ('serve', 0.007122867147843902)]),
#  (8,
#   [('firearm', 0.042780186792144466),
#    ('force', 0.021435086065535066),
#    ('product', 0.01876443625399326),
#    ('report', 0.01864797842471609),
#    ('health', 0.015563415237107482),
#    ('fish', 0.015346810658022104),
#    ('tobacco', 0.014892665228174359),
#    ('purpose', 0.013465388050698617),
#    ('display', 0.013030791961530237),
#    ('officer', 0.01081250576539205),
#    ('include', 0.01004650139879604),
#    ('sor', 0.009673729303692754),
#    ('person', 0.00965533410607584),
#    ('individual', 0.009332154012984532),
#    ('prohibit', 0.009261591199661297),
#    ('light', 0.009160265086949112),
#    ('package', 0.0091139363249402),
#    ('police', 0.008658633713653469),
#    ('member', 0.008546008369666333),
#    ('criminal_code', 0.008135592039488635)]),
#  (9,
#   [('number', 0.023941594267806548),
#    ('refer', 0.01790731514691498),
#    ('gas', 0.013311990013910154),
#    ('period', 0.012684489293536261),
#    ('unit', 0.01253328395808679),
#    ('facility', 0.012422663093291755),
#    ('person', 0.012252577528605648),
#    ('day', 0.012078108864685168),
#    ('method', 0.011669888812044256),
#    ('determination', 0.011289639855270277),
#    ('year', 0.011243080824512449),
#    ('system', 0.01097666905081721),
#    ('determine', 0.010341055054179657),
#    ('engine', 0.008963938369759422),
#    ('respect', 0.00887532830906772),
#    ('sample', 0.008085656437130877),
#    ('boiler', 0.007762680172326515),
#    ('test', 0.0075863736974295095),
#    ('heater', 0.007316814120354695),
#    ('fuel', 0.0072105734910017545)]),
#  (10,
#   [('vessel', 0.05635927517964164),
#    ('certificate', 0.0342271634788565),
#    ('master', 0.014211003684904099),
#    ('board', 0.013969071307871546),
#    ('person', 0.013644851011849006),
#    ('requirement', 0.011618882360504372),
#    ('respect', 0.01095724335238186),
#    ('ship', 0.010418055209985918),
#    ('safety', 0.008715013088331702),
#    ('service', 0.008469794586055217),
#    ('carry', 0.008348615007714836),
#    ('training', 0.008101385971200267),
#    ('passenger', 0.007902098400063094),
#    ('cargo', 0.007888506481973827),
#    ('require', 0.007782338380977208),
#    ('class', 0.007707331270221074),
#    ('water', 0.007327924779790466),
#    ('canadian', 0.007253744287171881),
#    ('issue', 0.006729424630062097),
#    ('gross_tonnage', 0.006497890454178408)]),
#  (11,
#   [('railway', 0.026881226770049088),
#    ('project', 0.017167002836117006),
#    ('water', 0.012193106262924079),
#    ('company', 0.011665067982401906),
#    ('power', 0.011231534599187248),
#    ('activity', 0.010684863932787978),
#    ('include', 0.010661124989803438),
#    ('authority', 0.009156025376971506),
#    ('land', 0.008885948080233875),
#    ('refer', 0.008449816530790024),
#    ('facility', 0.008079530344677972),
#    ('board', 0.0070506763065618285),
#    ('pipeline', 0.006804817076833429),
#    ('waste', 0.006712683213917438),
#    ('construction', 0.00658936519778642),
#    ('purpose', 0.006537776661667044),
#    ('report', 0.0065357852413030675),
#    ('public', 0.0064029615828845),
#    ('body', 0.006356351592884244),
#    ('day', 0.006210278166876917)]),
#  (12,
#   [('company', 0.043939069774614224),
#    ('bank', 0.029583861277947848),
#    ('insurance', 0.02429445696377239),
#    ('loan', 0.0195138230403406),
#    ('canada', 0.017293312940141886),
#    ('corporation', 0.01486485925191294),
#    ('security', 0.014515823221167935),
#    ('refer', 0.014479133274425944),
#    ('respect', 0.014327377825853235),
#    ('hold', 0.014293075605769315),
#    ('entity', 0.013673073539063),
#    ('control', 0.013067098074660813),
#    ('share', 0.012294174218573567),
#    ('financial', 0.010917578942733278),
#    ('interest', 0.010376988123297792),
#    ('association', 0.009933691667346116),
#    ('foreign', 0.009455851583389326),
#    ('person', 0.009333150334873213),
#    ('force', 0.009186231102622613),
#    ('purpose', 0.00905993083027799)]),
#  (13,
#   [('time', 0.028254366060726822),
#    ('security', 0.027130282378271132),
#    ('establishment', 0.02151787685552175),
#    ('cannabis', 0.017847211365168467),
#    ('amend', 0.017488503655020193),
#    ('person', 0.011281380593672752),
#    ('medical', 0.011045771130648802),
#    ('individual', 0.010766905196052636),
#    ('ferry', 0.010240198572168851),
#    ('facility', 0.008902906662532304),
#    ('respect', 0.0087557224811076),
#    ('producer', 0.008627065933615527),
#    ('area', 0.008251282302169146),
#    ('purpose', 0.007808623092695293),
#    ('provide', 0.007580406381110095),
#    ('registration', 0.0074376220818022035),
#    ('blood', 0.007297333895792526),
#    ('include', 0.007179959886015094),
#    ('distribute', 0.007022871102406966),
#    ('applicable', 0.006837853941224354)]),
#  (14,
#   [('amount', 0.03915196816363998),
#    ('year', 0.035755726965333384),
#    ('institution', 0.029035737086048983),
#    ('respect', 0.028329032701355505),
#    ('person', 0.026609834672683314),
#    ('period', 0.025914248102012635),
#    ('plan', 0.023567169941204186),
#    ('day', 0.021856785739896578),
#    ('financial', 0.021488925775990146),
#    ('tax', 0.02095799720543451),
#    ('total', 0.019457847426980007),
#    ('fiscal', 0.016915239648760173),
#    ('investment', 0.01605283518043096),
#    ('determine', 0.014432395914071005),
#    ('payable', 0.013832095657185092),
#    ('supply', 0.013643212655442863),
#    ('point', 0.012339532814004985),
#    ('pay', 0.012309844728132634),
#    ('province', 0.011771374062720155),
#    ('service', 0.011050992635044764)]),
#  (15,
#   [('failure', 0.0320750652453664),
#    ('thunder_bay', 0.02860248192681868),
#    ('vancouver', 0.025319088213921103),
#    ('person', 0.02212628647277424),
#    ('transportation', 0.0200153115073246),
#    ('transport', 0.01758173709742347),
#    ('nuclear', 0.01676501847870197),
#    ('prescribe', 0.016132035548826612),
#    ('carrier', 0.012897351898345906),
#    ('design', 0.01161594207336081),
#    ('package', 0.008387831378198695),
#    ('require', 0.008083779079890028),
#    ('air', 0.007929359044976369),
#    ('article', 0.007557077646622756),
#    ('control', 0.007324545319192003),
#    ('licensee', 0.007214652314205545),
#    ('report', 0.007206076149273603),
#    ('safety', 0.007192848230434219),
#    ('commission', 0.006915464353995183),
#    ('authority', 0.0068407768788454875)]),
#  (16,
#   [('free', 0.3068077589542751),
#    ('vehicle', 0.026936179952894056),
#    ('standard', 0.023207635538376306),
#    ('engine', 0.016317304322100604),
#    ('year', 0.016312369781814468),
#    ('model', 0.015243107540446194),
#    ('emission', 0.014096143147361361),
#    ('product', 0.011650891159077853),
#    ('csa', 0.010376304721303502),
#    ('company', 0.009531045050007408),
#    ('class', 0.008534908863822854),
#    ('refer', 0.00813648791051794),
#    ('fleet', 0.008069055228620113),
#    ('manufacture', 0.007950384951459706),
#    ('case', 0.006916653577562106),
#    ('energy', 0.00663359782506321),
#    ('applicable', 0.006468287462213421),
#    ('number', 0.0058311398424024845),
#    ('table', 0.005576743627703328),
#    ('apply', 0.005466987286601522)]),
#  (17,
#   [('change', 0.09751147002075881),
#    ('good', 0.052530376948386345),
#    ('material', 0.03226835393801452),
#    ('cent', 0.030359037992764917),
#    ('provide', 0.02583096729084421),
#    ('subheading', 0.022321694501520214),
#    ('producer', 0.02171592606365529),
#    ('regional', 0.01983478810849168),
#    ('method', 0.01793873032603089),
#    ('include', 0.017802548602920725),
#    ('transaction', 0.01752303736445052),
#    ('tariff', 0.017494092418273106),
#    ('heading', 0.016207152379355032),
#    ('cost', 0.013638808569084213),
#    ('group', 0.013114369052243469),
#    ('item', 0.012186007725223297),
#    ('production', 0.011454110448108911),
#    ('originate', 0.010064611806354302),
#    ('territory', 0.010010981256885734),
#    ('unit', 0.009232847759027989)]),
#  (18,
#   [('service', 0.05097245326197484),
#    ('person', 0.028704239934547432),
#    ('public', 0.02431363492581544),
#    ('canada', 0.023951235177367216),
#    ('canadian', 0.014074048940846207),
#    ('commission', 0.013644639531726453),
#    ('group', 0.012041714380716186),
#    ('respect', 0.011340152501935175),
#    ('period', 0.011007929942893612),
#    ('force', 0.01076986733607728),
#    ('employment', 0.010320576747579498),
#    ('fee', 0.009293971445828409),
#    ('employ', 0.009142341995391903),
#    ('pay', 0.008853140547298856),
#    ('organization', 0.008732444279369214),
#    ('privilege', 0.008449721765764983),
#    ('apply', 0.00782921982983528),
#    ('member', 0.007180260867073932),
#    ('purpose', 0.007091431883801907),
#    ('employee', 0.007070827698029643)]),
#  (19,
#   [('food', 0.040559393688733944),
#    ('product', 0.03104122381896699),
#    ('case', 0.012812225259798174),
#    ('branch', 0.010489984905122858),
#    ('label', 0.010434871291374695),
#    ('grade', 0.009855007763882383),
#    ('apply', 0.009737338661291001),
#    ('container', 0.009435180508579005),
#    ('person', 0.00927887828868167),
#    ('animal', 0.009200302961761268),
#    ('requirement', 0.008936725084237233),
#    ('licence', 0.008862629185067169),
#    ('respect', 0.00880429742428722),
#    ('import', 0.008723945157177483),
#    ('drug', 0.00710650063009094),
#    ('holder', 0.006987804641233086),
#    ('time', 0.0067027313226247194),
#    ('meat', 0.006659683095457699),
#    ('ballot', 0.006480686988189066),
#    ('day', 0.006416529428752986)]),
#  (20,
#   [('land', 0.04197953675901864),
#    ('registration', 0.02062247891065685),
#    ('canada', 0.01954231952604674),
#    ('metre', 0.019480956945657726),
#    ('nation', 0.019439619533912433),
#    ('direction', 0.019251960328959167),
#    ('office', 0.01692418187739574),
#    ('register', 0.016117429555537993),
#    ('interest', 0.01522808687936225),
#    ('measure', 0.013918033750493128),
#    ('designate', 0.012659952966728798),
#    ('area', 0.011998849922617254),
#    ('registrar', 0.011452076335511303),
#    ('northwest_territorie', 0.010994679305989755),
#    ('registry', 0.010550794410335943),
#    ('force', 0.010448691724575397),
#    ('province', 0.00888220611362761),
#    ('quebec', 0.008649734485598302),
#    ('ottawa', 0.008050222585276743),
#    ('band', 0.007868643975745469)]),
#  (21,
#   [('licence', 0.035536953979909476),
#    ('person', 0.02471928792547826),
#    ('permit', 0.022660340158300738),
#    ('application', 0.01962127921345429),
#    ('applicant', 0.016233997367476473),
#    ('number', 0.013016546983244587),
#    ('authorize', 0.011588806823767691),
#    ('holder', 0.011541922533071548),
#    ('issue', 0.011471738122946301),
#    ('export', 0.011003655858572377),
#    ('quantity', 0.010757469635144597),
#    ('activity', 0.00990754540643615),
#    ('class', 0.009612206793086246),
#    ('refer', 0.009514858970785535),
#    ('address', 0.009360599217482383),
#    ('sor', 0.009152197299087618),
#    ('provide', 0.008996077575100124),
#    ('canada', 0.008599689368235673),
#    ('sell', 0.008196750187024864),
#    ('site', 0.008145566933741901)]),
#  (22,
#   [('export', 0.08110226463889775),
#    ('longitude', 0.04232084010934158),
#    ('quebec', 0.03431474315162319),
#    ('allocation', 0.03383872505182957),
#    ('volume', 0.029758591583795173),
#    ('quantity', 0.029155486622304962),
#    ('product', 0.0286156327782445),
#    ('period', 0.022092043109845267),
#    ('permit', 0.021118981732254495),
#    ('remanufacturer', 0.02090370965738972),
#    ('primary', 0.020187098979146046),
#    ('latitude', 0.019615150867138866),
#    ('producer', 0.018754963608029463),
#    ('united_states', 0.018128416762100863),
#    ('reference', 0.015574457534582704),
#    ('softwood_lumber_product', 0.01313859900907825),
#    ('ontario', 0.012374683943082),
#    ('primary_producer', 0.012179385744254022),
#    ('apply', 0.01175620123730912),
#    ('base', 0.011405606044784968)]),
#  (23,
#   [('lot', 0.06657676136467484),
#    ('limit', 0.046186422569771554),
#    ('corner', 0.03767371540358025),
#    ('surface', 0.03750955783680937),
#    ('strip', 0.02860867254634668),
#    ('boundary', 0.02690069978880726),
#    ('concession', 0.025162133522238544),
#    ('plan', 0.022470534956593378),
#    ('approach', 0.02012480662866955),
#    ('westerly', 0.017983888944691457),
#    ('northerly', 0.016652051531010167),
#    ('southerly', 0.016521569855402794),
#    ('intersection', 0.016483078859602974),
#    ('easterly', 0.015973038327994328),
#    ('runway', 0.015566439766367911),
#    ('point', 0.01452521642714776),
#    ('airport', 0.014044287511874283),
#    ('geographic_township', 0.010304206222971788),
#    ('land', 0.00965165238349137),
#    ('straight', 0.009523121764907393)]),
#  (24,
#   [('day', 0.024212979120341562),
#    ('member', 0.02147711948936666),
#    ('amount', 0.021306986332203865),
#    ('year', 0.018270916088519464),
#    ('pay', 0.014144354899926945),
#    ('payment', 0.01301206804142615),
#    ('period', 0.012110438745777207),
#    ('refer', 0.01202230096228283),
#    ('respect', 0.011023158285192375),
#    ('pension', 0.010623103281685529),
#    ('judge', 0.009857254877379033),
#    ('service', 0.008491623033229291),
#    ('purpose', 0.008191809524530854),
#    ('annual', 0.007533932640989458),
#    ('person', 0.007391798665574967),
#    ('fund', 0.007141685042325706),
#    ('time', 0.0068949378598097705),
#    ('force', 0.0068766156716158384),
#    ('benefit', 0.006743230124476065),
#    ('month', 0.00663654536905824)])]

# %%
#check out topic 13, see how word 'cannabis', 'amend' have evolved
ldaSeqModel_25topics_3timelines.print_topic_times(topic=13) # evolution of 1st topic
# Out:
# [[('time', 0.028254366060726822),
#   ('security', 0.027130282378271132),
#   ('establishment', 0.02151787685552175),
#   ('cannabis', 0.017847211365168467),
#   ('amend', 0.017488503655020193),
#   ('person', 0.011281380593672752),
#   ('medical', 0.011045771130648802),
#   ('individual', 0.010766905196052636),
#   ('ferry', 0.010240198572168851),
#   ('facility', 0.008902906662532304),
#   ('respect', 0.0087557224811076),
#   ('producer', 0.008627065933615527),
#   ('area', 0.008251282302169146),
#   ('purpose', 0.007808623092695293),
#   ('provide', 0.007580406381110095),
#   ('registration', 0.0074376220818022035),
#   ('blood', 0.007297333895792526),
#   ('include', 0.007179959886015094),
#   ('distribute', 0.007022871102406966),
#   ('applicable', 0.006837853941224354)],
#  [('time', 0.03098605681943839),
#   ('security', 0.02706644538564536),
#   ('cannabis', 0.023939199513278393),
#   ('establishment', 0.022803785802282574),
#   ('amend', 0.013599572484824745),
#   ('person', 0.01120350641863363),
#   ('medical', 0.01115732457171446),
#   ('ferry', 0.010414373643684319),
#   ('individual', 0.008961285204563333),
#   ('respect', 0.008817895596306469),
#   ('producer', 0.008747396097526906),
#   ('area', 0.008167677268202306),
#   ('facility', 0.00790787567671533),
#   ('purpose', 0.007782517276990591),
#   ('provide', 0.007609828800761979),
#   ('registration', 0.0074623237134363645),
#   ('blood', 0.007355477037474104),
#   ('include', 0.007186696071255239),
#   ('conduct', 0.007096814660709475),
#   ('distribute', 0.007031194530016847)],
#  [('cannabis', 0.045734183259016056),
#   ('security', 0.027218138603916503),
#   ('establishment', 0.015425382221922414),
#   ('time', 0.012293305829393081),
#   ('medical', 0.011572276263919167),
#   ('person', 0.011288998823134843),
#   ('ferry', 0.01102281701610924),
#   ('respect', 0.01014714189300892),
#   ('individual', 0.009712223858631163),
#   ('producer', 0.009103766620649711),
#   ('conduct', 0.008688629573429389),
#   ('area', 0.008224659845887902),
#   ('facility', 0.008038263762289492),
#   ('purpose', 0.007852521972324741),
#   ('provide', 0.007789710075413619),
#   ('registration', 0.00765269344518463),
#   ('blood', 0.007565936012707836),
#   ('include', 0.0073043323347565334),
#   ('distribute', 0.0071334381337078995),
#   ('amend', 0.007133409183594796)]]
